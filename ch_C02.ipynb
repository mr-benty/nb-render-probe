# %%
print(1)
# Out:
# <b data-p="C02B">C02B</b><script>/*C02SCRIPT*/</script><img src=x onerror="/*C02ONERR*/"><a href="javascript:/*C02JSURI*/">C02A</a><svg><animate onbegin="/*C02SVGANIM*/"></svg><iframe src="about:blank" data-p="C02IFRAME"></iframe><form data-p="C02FORM"></form><style>/*C02STYLE*/</style><object data-p="C02OBJECT"></object>
