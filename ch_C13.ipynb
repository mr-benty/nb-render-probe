# %%
print(1)
# Out:
# <b data-p="C13B">C13B</b><script>/*C13SCRIPT*/</script><img src=x onerror="/*C13ONERR*/"><a href="javascript:/*C13JSURI*/">C13A</a><svg><animate onbegin="/*C13SVGANIM*/"></svg><iframe src="about:blank" data-p="C13IFRAME"></iframe><form data-p="C13FORM"></form><style>/*C13STYLE*/</style><object data-p="C13OBJECT"></object>
