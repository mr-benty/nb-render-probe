# %%
print(1)
# Out:
# <b data-p="C05B">C05B</b><script>/*C05SCRIPT*/</script><img src=x onerror="/*C05ONERR*/"><a href="javascript:/*C05JSURI*/">C05A</a><svg><animate onbegin="/*C05SVGANIM*/"></svg><iframe src="about:blank" data-p="C05IFRAME"></iframe><form data-p="C05FORM"></form><style>/*C05STYLE*/</style><object data-p="C05OBJECT"></object>
