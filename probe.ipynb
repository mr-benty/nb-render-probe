# %% [markdown]
# <b data-p="C01B">C01B</b><script>/*C01SCRIPT*/</script><img src=x onerror="/*C01ONERR*/"><a href="javascript:/*C01JSURI*/">C01A</a><svg><animate onbegin="/*C01SVGANIM*/"></svg><iframe src="about:blank" data-p="C01IFRAME"></iframe><math><mtext></mtext></math><form data-p="C01FORM"></form><style>/*C01STYLE*/</style><object data-p="C01OBJECT"></object><link rel="stylesheet" data-p="C01LINK">

# %%
print(1)
# Out:
# <b data-p="C02B">C02B</b><script>/*C02SCRIPT*/</script><img src=x onerror="/*C02ONERR*/"><a href="javascript:/*C02JSURI*/">C02A</a><svg><animate onbegin="/*C02SVGANIM*/"></svg><iframe src="about:blank" data-p="C02IFRAME"></iframe><math><mtext></mtext></math><form data-p="C02FORM"></form><style>/*C02STYLE*/</style><object data-p="C02OBJECT"></object><link rel="stylesheet" data-p="C02LINK">

# %%
print(2)

# %%
print(3)
# Out:
# <b data-p="C04B">C04B</b><script>/*C04SCRIPT*/</script><img src=x onerror="/*C04ONERR*/"><a href="javascript:/*C04JSURI*/">C04A</a><svg><animate onbegin="/*C04SVGANIM*/"></svg><iframe src="about:blank" data-p="C04IFRAME"></iframe><math><mtext></mtext></math><form data-p="C04FORM"></form><style>/*C04STYLE*/</style><object data-p="C04OBJECT"></object><link rel="stylesheet" data-p="C04LINK">

# %%
print(4)
# Out:
# <b data-p="C05B">C05B</b><script>/*C05SCRIPT*/</script><img src=x onerror="/*C05ONERR*/"><a href="javascript:/*C05JSURI*/">C05A</a><svg><animate onbegin="/*C05SVGANIM*/"></svg><iframe src="about:blank" data-p="C05IFRAME"></iframe><math><mtext></mtext></math><form data-p="C05FORM"></form><style>/*C05STYLE*/</style><object data-p="C05OBJECT"></object><link rel="stylesheet" data-p="C05LINK">

# %%
print(5)

# %% [raw]
# <b data-p="C07B">C07B</b><script>/*C07SCRIPT*/</script><img src=x onerror="/*C07ONERR*/"><a href="javascript:/*C07JSURI*/">C07A</a><svg><animate onbegin="/*C07SVGANIM*/"></svg><iframe src="about:blank" data-p="C07IFRAME"></iframe><math><mtext></mtext></math><form data-p="C07FORM"></form><style>/*C07STYLE*/</style><object data-p="C07OBJECT"></object><link rel="stylesheet" data-p="C07LINK">

# %%
print(6)
# Out:
# <b data-p="C08B">C08B</b><script>/*C08SCRIPT*/</script><img src=x onerror="/*C08ONERR*/"><a href="javascript:/*C08JSURI*/">C08A</a><svg><animate onbegin="/*C08SVGANIM*/"></svg><iframe src="about:blank" data-p="C08IFRAME"></iframe><math><mtext></mtext></math><form data-p="C08FORM"></form><style>/*C08STYLE*/</style><object data-p="C08OBJECT"></object><link rel="stylesheet" data-p="C08LINK">

# %%
print(7)
# Out:
# <b data-p="C09B">C09B</b><script>/*C09SCRIPT*/</script><img src=x onerror="/*C09ONERR*/"><a href="javascript:/*C09JSURI*/">C09A</a><svg><animate onbegin="/*C09SVGANIM*/"></svg><iframe src="about:blank" data-p="C09IFRAME"></iframe><math><mtext></mtext></math><form data-p="C09FORM"></form><style>/*C09STYLE*/</style><object data-p="C09OBJECT"></object><link rel="stylesheet" data-p="C09LINK">

# %%
print(8)

# %%
<b data-p="C11B">C11B</b><script>/*C11SCRIPT*/</script><img src=x onerror="/*C11ONERR*/"><a href="javascript:/*C11JSURI*/">C11A</a><svg><animate onbegin="/*C11SVGANIM*/"></svg><iframe src="about:blank" data-p="C11IFRAME"></iframe><math><mtext></mtext></math><form data-p="C11FORM"></form><style>/*C11STYLE*/</style><object data-p="C11OBJECT"></object><link rel="stylesheet" data-p="C11LINK">

# %%
print(10)
