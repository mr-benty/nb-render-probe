# %%
print(1)
# Out:
# <b data-p="C04B">C04B</b><script>/*C04SCRIPT*/</script><img src=x onerror="/*C04ONERR*/"><a href="javascript:/*C04JSURI*/">C04A</a><svg><animate onbegin="/*C04SVGANIM*/"></svg><iframe src="about:blank" data-p="C04IFRAME"></iframe><form data-p="C04FORM"></form><style>/*C04STYLE*/</style><object data-p="C04OBJECT"></object>
